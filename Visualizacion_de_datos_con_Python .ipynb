# %% [markdown]
# #Visualización de datos con Python: Matplotlib, Seaborn y Plotly

# %%
import pandas as pd

# %%
#IMPORTAR CSV CON DATOS DE INMIGRANTES EN CANADA DE 1980 HASTA 2013

archivo = 'https://raw.githubusercontent.com/alura-es-cursos/2063-visualizacion-de-datos-con-bibliotecas-de-python/refs/heads/main/inmigrantes_canada.csv'

pd.read_csv(archivo)
# Out:
#                   Pais Continente            Region  1980  1981  1982  1983  \
# 0           Afganistán       Asia       Sur de Asia    16    39    39    47
# 1              Albania     Europa     Sur de Europa     1     0     0     0
# 2              Argelia     África   Norte de África    80    67    71    69
# 3      Samoa Americana    Oceanía         Polinesia     0     1     0     0
# 4              Andorra     Europa     Sur de Europa     0     0     0     0
# ..                 ...        ...               ...   ...   ...   ...   ...
# 190            Vietnam       Asia  Sudeste Asiático  1191  1829  2162  3404
# 191  Sahara Occidental     África   Norte de África     0     0     0     0
# 192              Yemen       Asia   Asia Occidental     1     2     1     6
# 193             Zambia     África   África Oriental    11    17    11     7
# 194           Zimbabue     África   África Oriental    72   114   102    44
#
# ...

# %%
df = pd.read_csv(archivo)

df.shape
# Out:
# (195, 38)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Pais        195 non-null    object
#  1   Continente  195 non-null    object
#  2   Region      195 non-null    object
#  3   1980        195 non-null    int64
#  4   1981        195 non-null    int64
#  5   1982        195 non-null    int64
#  6   1983        195 non-null    int64
#  7   1984        195 non-null    int64
#  8   1985        195 non-null    int64
#  9   1986        195 non-null    int64
#  10  1987        195 non-null    int64
#  11  1988        195 non-null    int64
#  12  1989        195 non-null    int64
#  13  1990        195 non-null    int64
#  14  1991        195 non-null    int64
#  15  1992        195 non-null    int64
#  16  1993        195 non-null    int64
#  17  1994        195 non-null    int64
#  18  1995        195 non-null    int64
# ...

# %%
#COLOCAMOS LA COLUMNA PAIS COMO INDICE

df.set_index('Pais', inplace=True)
df
# Out:
#                   Continente            Region  1980  1981  1982  1983  1984  \
# Pais
# Afganistán              Asia       Sur de Asia    16    39    39    47    71
# Albania               Europa     Sur de Europa     1     0     0     0     0
# Argelia               África   Norte de África    80    67    71    69    63
# Samoa Americana      Oceanía         Polinesia     0     1     0     0     0
# Andorra               Europa     Sur de Europa     0     0     0     0     0
# ...                      ...               ...   ...   ...   ...   ...   ...
# Vietnam                 Asia  Sudeste Asiático  1191  1829  2162  3404  7583
# Sahara Occidental     África   Norte de África     0     0     0     0     0
# Yemen                   Asia   Asia Occidental     1     2     1     6     0
# Zambia                África   África Oriental    11    17    11     7    16
# Zimbabue              África   África Oriental    72   114   102    44    32
#
# ...

# %%
#CREAMOS UNA LISTA CON TODOS LOS AÑOS

anos = list(map(str,range(1980,2014)))
anos
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
#CONSULTAR LOS INMIGRANTES SOLO DEL PAIS COLOMBIA EN TODOS LOS AÑOS

colombia = df.loc['Colombia',anos]
colombia
# Out:
# 1980     266
# 1981     326
# 1982     360
# 1983     244
# 1984     235
# 1985     214
# 1986     257
# 1987     376
# 1988     352
# 1989     439
# 1990     614
# 1991     652
# 1992     582
# 1993     464
# 1994     375
# 1995     371
# 1996     381
# 1997     578
# 1998     929
# 1999    1306
# 2000    2259
# 2001    2965
# 2002    3283
# 2003    4318
# 2004    4566
# 2005    6424
# 2006    6535
# 2007    5357
# 2008    5452
# 2009    4652
# 2010    5218
# 2011    4366
# 2012    3741
# 2013    3631
# Name: Colombia, dtype: object

# %%
#CREAR DICCIONARIO CON LAS DOS LISTAS AÑO Y COLOMBIA

col_dic = {'Año':colombia.index.tolist(), 'Inmigrantes':colombia.values.tolist()}
col_dic
# Out:
# {'Año': ['1980',
#   '1981',
#   '1982',
#   '1983',
#   '1984',
#   '1985',
#   '1986',
#   '1987',
#   '1988',
#   '1989',
#   '1990',
#   '1991',
#   '1992',
#   '1993',
#   '1994',
#   '1995',
#   '1996',
#   '1997',
#   '1998',
#   '1999',
#   '2000',
#   '2001',
#   '2002',
#   '2003',
#   '2004',
#   '2005',
#   '2006',
#   '2007',
#   '2008',
#   '2009',
#   '2010',
#   '2011',
#   '2012',
#   '2013'],
#  'Inmigrantes': [np.int64(266),
#   np.int64(326),
#   np.int64(360),
#   np.int64(244),
#   np.int64(235),
#   np.int64(214),
#   np.int64(257),
#   np.int64(376),
#   np.int64(352),
#   np.int64(439),
#   np.int64(614),
#   np.int64(652),
#   np.int64(582),
#   np.int64(464),
#   np.int64(375),
#   np.int64(371),
#   np.int64(381),
#   np.int64(578),
#   np.int64(929),
#   np.int64(1306),
#   np.int64(2259),
#   np.int64(2965),
#   np.int64(3283),
#   np.int64(4318),
#   np.int64(4566),
#   np.int64(6424),
#   np.int64(6535),
#   np.int64(5357),
#   np.int64(5452),
# ...

# %%
#CREAR UN DATAFRAME CON LOS DATOS DE COLOMBIA

datos_col = pd.DataFrame(col_dic)

datos_col.tail()
# Out:
#      Año  Inmigrantes
# 29  2009         4652
# 30  2010         5218
# 31  2011         4366
# 32  2012         3741
# 33  2013         3631

# %%
#CREAMOS UN GRAFICO PARA VISUALIZAR LOS DATOS CON LA LIBRERIA matplotlib

import matplotlib.pyplot as plt

plt.figure(figsize=(8,4)) #TAMAÑO DEL GRAFICO
plt.plot(datos_col['Año'],datos_col['Inmigrantes']) #COLUMNAS DE DICCIONARIO
plt.xticks(['1980','1985','1990','1995','2000','2005','2010']) #AÑOS COLOCADOS DE 5 EN 5
plt.title('Inmigración de Colombianos a Canada')
plt.ylabel('Numero de Inmigrantes') #TITULO DEL EJE Y
plt.xlabel('Años') #TITULO DEL EJE X
plt.show() #MOSTRAR EL GRAFICO

# %% [markdown]
# ##**Desafío: comparando tendencias migratorias**
#
#  Ahora tenemos una nueva tarea: crear un gráfico de líneas comparando los números de inmigrantes de Brasil y Argentina a Canadá, los dos países más grandes de Sudamérica.
#
#  Prepárate para sumergirte en las fascinantes líneas que conectan estos países sudamericanos con el territorio canadiense. En esta misión, la elaboración de este gráfico puede ser útil para comprender las tendencias migratorias de estos países a Canadá a lo largo del tiempo y cómo se comparan entre sí. Al analizar estos factores, podemos obtener una visión más amplia del panorama migratorio en Sudamérica.
#
# ¡No te preocupes!
#
# Esta nueva tarea es más desafiante, ya que requiere un análisis comparativo entre dos países. Sin embargo, también te permitirá obtener un aprendizaje enriquecedor. Por lo tanto, explora las diversas posibilidades y recuerda los elementos esenciales de un gráfico: título, etiquetas en los ejes x e y y las marcas del eje x, que deben definirse cada 5 años.
#
# Además, tendrás que descubrir cómo agregar una leyenda para poder identificar la línea de cada país. Siguiendo estas instrucciones, habrás construido un gráfico sólido que te permitirá un análisis significativo y profundo.

# %%
#FILTRADOS LOS DATOS DE BRASIL Y ARGENTINA

df_comparacion = df.loc[['Brasil', 'Argentina'], anos]
df_comparacion.head()
# Out:
#            1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  ...  \
# Pais                                                                   ...
# Brasil      211   220   192   139   145   130   205   244   394   650  ...
# Argentina   368   426   626   241   237   196   213   519   374   538  ...
#
#            2004  2005  2006  2007  2008  2009  2010  2011  2012  2013
# Pais
# Brasil      917   969  1181  1746  2138  2509  2598  1508  1642  1714
# Argentina  1591  1153   847   620   540   467   459   278   263   282
#
# [2 rows x 34 columns]

# %%
#TRANSFORMAR LOS DATOS EN COLUMNAS CON LA FUNCION Transponer

df_comparacion = df_comparacion.T
df_comparacion
# Out:
# Pais  Brasil  Argentina
# 1980     211        368
# 1981     220        426
# 1982     192        626
# 1983     139        241
# 1984     145        237
# 1985     130        196
# 1986     205        213
# 1987     244        519
# 1988     394        374
# 1989     650        538
# 1990     650        678
# 1991     877        763
# 1992    1066       1023
# 1993     866       1022
# 1994     566        366
# 1995     572        380
# 1996     586        396
# 1997     591        391
# 1998     531        349
# 1999     626        318
# 2000     845        427
# 2001     847        635
# 2002     745        865
# 2003     839       1745
# 2004     917       1591
# 2005     969       1153
# 2006    1181        847
# 2007    1746        620
# 2008    2138        540
# 2009    2509        467
# 2010    2598        459
# 2011    1508        278
# 2012    1642        263
# 2013    1714        282

# %%
#CREAR EL GRAFICO CON LOS DATOS OBTENIDOS

plt.plot(df_comparacion['Brasil'], label='Brasil')
plt.plot(df_comparacion['Argentina'], label='Argentina')
plt.title('Inmigración de Brasil y Argentina a Canadá')
plt.xlabel('Año')
plt.ylabel('Número de Inmigrantes')
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.legend()
plt.show()

# %%
#OTRA FORMA DE MOSTRAR EL GRAFICO UTILIZANDO UNA VARIABLE COMO ax
#ESTE METODO TAMBIEN FUNCIONA PARA COLOCAR DOS GRAFICOS JUNTOS

fig, ax = plt.subplots(figsize=(8,4)) #TAMBIEN PUEDE SER UTILIZADO PARA VARIOS GRAFICOS
ax.plot(datos_col['Año'],datos_col['Inmigrantes']) # LAS COLUMNAS
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) # COLOCAR LA MEJOR LOCACION DE 5 EN 5
ax.set_title('inmigracion de Colombianos hacia Canada\n1980 - 2013')
ax.set_xlabel('Año')
ax.set_ylabel('Numero de inmigrantes')
plt.show()

# %%
#REALIZAR DOS GRAFICOS JUNTOS

fig, axs = plt.subplots(1,2, figsize=(15,4)) #COLOCAMOS 1 PARA UNA SOLA FILA Y EL 2 PARA 2 COLUMNAS (SE PUEDEN COLOCAR MAS PARA AGRAGAR MAS FILAS Y COLUMNAS CON OTROS GRAFICOS)
axs[0].plot(datos_col['Año'],datos_col['Inmigrantes']) # LAS COLUMNAS
axs[0].set_title('inmigracion de Colombianos hacia Canada\n1980 - 2013')
axs[0].set_xlabel('Año')
axs[0].set_ylabel('Numero de inmigrantes')
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5)) # COLOCAR LA MEJOR LOCACION DE 5 EN 5
axs[0].grid() #AGREGAR CUADRICULA A LOS GRAFICOS

axs[1].boxplot(datos_col['Inmigrantes']) #GRAFICO boxplot PARA MOSTRAR DATOS ESTADISTICOS DEL TOTAL DE DATOS EN EL DATAFRAME(GRAFICA LA INFORMACION OBTENIDA CON EL METODO describe() APLICADO AL DATAFRAME)
axs[1].set_title('Boxplot de la inmigracion de Colombianos hacia Canada\n1980 - 2013')
axs[1].set_xlabel('Colombia')
axs[1].set_ylabel('Numero de inmigrantes')
axs[1].grid()

plt.show()

# %%
#EL GRAFICO boxplot GRAFICA LOS DATOS DEL METODO describe() APLICADO AL DATAFRAME
datos_col.describe()
# Out:
#        Inmigrantes
# count    34.000000
# mean   2120.235294
# std    2163.761316
# min     214.000000
# 25%     372.000000
# 50%     633.000000
# 75%    4173.750000
# max    6535.000000

# %%
#MOSTRAR CUATRO GRAFICOS COLOCANDO 2 FILAS Y 2 COLUMNAS

fig, axs = plt.subplots(2,2, figsize=(15,6)) #COLOCAR 2 FILAS Y 2 COLUMNAS PARA COLOCAR 4 CUATRO GRAFICOS
fig.subplots_adjust(hspace=0.5,wspace=0.3) #ESPACION ENTRE LOS GRAFICOS
fig.suptitle('Inmigración de los 4 mayores paises sudamericanos\nhacia Canada desde 1980 a 2013') #COLOCAR TITULO SUPERIROR

axs[0,0].plot(df.loc['Colombia',anos])
axs[0,0].set_title('Columbia')

axs[0,1].plot(df.loc['Brasil',anos])
axs[0,1].set_title('Brasil')

axs[1,0].plot(df.loc['Argentina',anos])
axs[1,0].set_title('Argentina')

axs[1,1].plot(df.loc['Perú',anos])
axs[1,1].set_title('Perú')

ymin = 0 #VALOR MINIMO DONDE COMENZARA LA ALTURA DE LOS GRAFICO
ymax = 7000 #VALOR MAXIMO DONDE TERMINA LA ALTURA DE LOS GRAFICOS, YA QUE SOBRE PASA LOS 6000 HABITANTES EN UNO DE LOS GRAFICOS SE COLOCA UN NUMERO SUPERIOR

for ax in axs.ravel(): #ravel PERMITE COLOCAR ARRAYS MULTIDIMENSIONAES EN UN UNIDIMENSIONALES PARA ITERAR TODAS LAS GRAFICAS
  ax.set_ylim(ymin,ymax) #AGREAR LOS LIMITES MAXIMO Y MINIMO DE ALTURA A TODOS LOS GRAFICOS POR IGUAL

for ax in axs.flat: #flat PERMITE ITERAR EN CADA UNO DE LOS GRAFICOS PARA COLOCAR:
  ax.xaxis.set_major_locator(plt.MultipleLocator(5)) #LA MEJOR LOCACION PARA COLOCAR LOS AÑOS
  ax.set_xlabel('Año') # COLOCAR LA MISMA ETIQUETA ABAJO
  ax.set_ylabel('Numero de Inmigrantes')# Y COLOCAR LA MISMA ETIQUETA A LA IZQUIERDA
  ax.grid() #CUADRICULAR TODOS LOS GRAFICOS

plt.show()

# %% [markdown]
# ##**Desafío: visualizando datos de ventas de tiendas diferentes**
#
# Trabajas como Analista de Datos en una empresa minorista y te asignaron la tarea de crear una figura con subgráficos que muestre la variación en el número de ventas en cuatro tiendas diferentes a lo largo de un año. La gerencia de la empresa necesita visualizar claramente las tendencias de ventas en cada tienda, para que puedan tomar decisiones estratégicas sobre inventarios y acciones de marketing. Para ello, debes crear cuatro subgráficos dispuestos en dos filas y dos columnas, donde cada subgráfico represente una tienda diferente. En este desafío, cada subgráfico debe presentar un gráfico de líneas que muestre la variación del número de ventas a lo largo de los meses del año.
#
# ¡Ahora es el momento de mostrar tus habilidades en análisis de datos y visualización! Para crear el DataFrame con el número de ventas de las tiendas y crear la figura, utiliza la siguiente información:
#
# Consejo: Para facilitar la creación de los subgráficos, puedes definir la columna "tiendas" como índice del DataFrame y utilizar la propiedad loc de la biblioteca Pandas para trazar cada una de las tiendas.
#
# ¡No olvides agregar un título general a la figura, títulos a los subgráficos y etiquetas a los ejes! Además, asegúrate del tamaño de la figura y del espaciado entre los subgráficos.

# %%
tiendas = ['A', 'B', 'C', 'D']
ventas_2022 = {'Ene': [100, 80, 150, 50],
    'Feb': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abr': [180, 110, 230, 90],
    'May': [220, 190, 350, 200],
    'Jun': [230, 150, 280, 120],
    'Jul': [250, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Sep': [240, 160, 290, 130],
    'Oct': [220, 140, 270, 110],
    'Nov': [400, 220, 350, 190],
    'Dec': [300, 350, 400, 250]}


#CREAMOS EL DICCIONARIO CON LAS TIENDAS
tiendas_ventas_2022 = {'Tiendas':tiendas}
#AGREGAMOS LAS VENTAS AL DICCIONARIO DE LAS TIENDAS
tiendas_ventas_2022.update(ventas_2022)
#CREAMOS EL DATAFRAME
tiendas_ventas_2022 = pd.DataFrame(tiendas_ventas_2022)
#COLOCAMOS LAS TIENDAS COMO INDEX EN EL DATAFRAM
tiendas_ventas_2022.set_index('Tiendas', inplace=True)

tiendas_ventas_2022

#CREAMOS UNA LISTA CON TODOS LOS MESES
meses = list(ventas_2022.keys())

#UTILIZAMOS loc PARA LOCALIZAR LA TIENDA Y LOS MESES
tienda_A = tiendas_ventas_2022.loc['A',meses]
tienda_A

#CREAMOS EL GRAFICO

fig2, axs2 = plt.subplots(2,2, figsize=(15,6)) #COLOCAR 2 FILAS Y 2 COLUMNAS PARA COLOCAR 4 CUATRO GRAFICOS
fig2.subplots_adjust(hspace=0.5,wspace=0.3) #ESPACION ENTRE LOS GRAFICOS
fig2.suptitle('Tendencias de ventas en 2022') #COLOCAR TITULO SUPERIROR

axs2[0,0].plot(tiendas_ventas_2022.loc['A',meses])
axs2[0,0].set_title('Tienda A')


axs2[0,1].plot(tiendas_ventas_2022.loc['B',meses])
axs2[0,1].set_title('Tienda B')

axs2[1,0].plot(tiendas_ventas_2022.loc['C',meses])
axs2[1,0].set_title('Tienda C')

axs2[1,1].plot(tiendas_ventas_2022.loc['D',meses])
axs2[1,1].set_title('Tienda D')

ymaximo = 500
yminimo = 0

for ax in axs2.ravel():
  ax.set_ylim(yminimo,ymaximo)

for ax in axs2.flat:
  ax.set_ylabel('Cantidad de ventas')
  ax.set_xlabel('Meses')
  ax.grid()

plt.show()

# %%
#MÁS PERSONALIZACION DEL GRAFICO

fig, ax = plt.subplots(figsize=(8,3))
ax.plot(datos_col['Año'],datos_col['Inmigrantes'], lw=3, marker='o', color='g') # lw ES PARA EL GROSOR DE LA LINEA Y marker PARA AGREGAR LOS PUNTOS EN LA LINEA y color apra cmabiar el color de la linea
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) # COLOCAR LA MEJOR LOCACION DE 5 EN 5
ax.set_title('inmigracion de Colombianos hacia Canada\n1980 - 2013', fontsize=18, loc='left') # fontsize TAMAÑO DE LA FUENTE Y loc ALINEACIÓN DEL TITULO
ax.set_xlabel('Año', fontsize=14) #fontsize TAMAÑO DE LA LETRAS
ax.set_ylabel('Numero de inmigrantes', fontsize=14) #fontsize TAMAÑO DE LA FUENTE
ax.yaxis.set_tick_params(labelsize=12) #fontsize TAMAÑO DE LA FUENTE
ax.xaxis.set_tick_params(labelsize=12) #fontsize TAMAÑO DE LA FUENTE
ax.grid(linestyle='--') #COLOCAR LINEA PUNTEADA EN LA CUADRICULA
plt.show()

# %%
#SELECCIONAR PAISES DE SUDAMERICA

sudamerica = df.query('Region == "América del Sur"')
sudamerica.head(10)
# Out:
#                            Continente           Region  1980  1981  1982  \
# Pais
# Argentina  América Latina y el Caribe  América del Sur   368   426   626
# Bolivia    América Latina y el Caribe  América del Sur    44    52    42
# Brasil     América Latina y el Caribe  América del Sur   211   220   192
# Chile      América Latina y el Caribe  América del Sur  1233  1069  1078
# Colombia   América Latina y el Caribe  América del Sur   266   326   360
# Ecuador    América Latina y el Caribe  América del Sur   238   207   184
# Guyana     América Latina y el Caribe  América del Sur  2334  2943  3575
# Paraguay   América Latina y el Caribe  América del Sur    45    26    32
# Perú       América Latina y el Caribe  América del Sur   317   456   401
# Surinam    América Latina y el Caribe  América del Sur    15    10    21
#
#            1983  1984  1985  1986  1987  ...  2005  2006  2007  2008  2009  \
# Pais                                     ...
# ...

# %%
#GRAFICO BARRA VERTICALES

colores = ['royalblue','orange','forestgreen','orchid','purple',
            'brown','slateblue','gray','olive','navy','teal','tomato']

fig, ax =plt.subplots(figsize=(15,5))

ax.bar(sudamerica.index, sudamerica['Total'],color=colores) #bar COLOCA LAS BARRAS DEL GRAFICO VERTICALES
ax.set_title('Inmigración de Sudamericanos a Canada\ndurante el periodo de 1980 hasta 2013', loc='left', fontsize=18)
ax.set_xlabel('')
ax.set_ylabel('Número de inmigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

plt.show()

# %%
#GRAFICO BARRA HORIZONTALES

colores = ['royalblue','orange','forestgreen','orchid','purple',
            'brown','slateblue','gray','olive','navy','teal','tomato']

fig, ax =plt.subplots(figsize=(15,5))

ax.barh(sudamerica.index, sudamerica['Total'],color=colores) #barh COLOCA LAS BARRAS DEL GRAFICO HORIZONTALES
ax.set_title('Inmigración de Sudamericanos a Canada\ndurante el periodo de 1980 hasta 2013', loc='left', fontsize=18)
ax.set_ylabel('')
ax.set_xlabel('Número de inmigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

plt.show()

# %%
#ORDENAR EL GRAFICO DE MANERA ASCENDENTE

sudamerica_sorted = sudamerica.sort_values('Total',ascending = True)

colores = ['royalblue','orange','forestgreen','orchid','purple',
            'brown','slateblue','gray','olive','navy','teal','tomato']

fig, ax =plt.subplots(figsize=(15,5))

ax.barh(sudamerica_sorted.index, sudamerica_sorted['Total'],color=colores) #barh COLOCA LAS BARRAS DEL GRAFICO HORIZONTALES
ax.set_title('Inmigración de Sudamericanos a Canada\ndurante el periodo de 1980 hasta 2013', loc='left', fontsize=18)
ax.set_ylabel('')
ax.set_xlabel('Número de inmigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

plt.show()

# %%
#COLOREAR SOLO EL PAIS DE COLOMBIA PARA QUE RESALTE

sudamerica_sorted = sudamerica.sort_values('Total',ascending = True)
colores=[]

for pais in sudamerica_sorted.index:
  if pais == 'Colombia':
    colores.append('green')
  else:
    colores.append('silver')

fig, ax =plt.subplots(figsize=(15,5))

ax.barh(sudamerica_sorted.index, sudamerica_sorted['Total'],color=colores) #barh COLOCA LAS BARRAS DEL GRAFICO HORIZONTALES
ax.set_title('Sudamérica: Colombia es el segundo pais con mas migrantes\nhacia Canada durante el periodo de 1980 - 2013', loc='left', fontsize=18)
ax.set_ylabel('')
ax.set_xlabel('Número de inmigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

plt.show()

# %% [markdown]
# En la misma gráfica, vamos a iterar y utilizar la función enumerate para poder enumerar cada uno de los valores totales. Entonces, for i, j in enumerate, ¿qué queremos enumerar? Nuestro dataframe Sudamérica_sorted, específicamente la columna totales. Al iterar allí, tendremos cada valor total con un número de referencia.
#
# Lo que hacemos es lo siguiente: utilizamos ax.text para colocar el valor del texto. Debemos especificar la posición, tanto en x como en y. La posición en x la calculamos con la variable j más 20, añadiendo 20 píxeles. La posición en y la dejamos en i, sin añadir ni quitar nada.
#
# Queremos que se escriba el valor total, que sería j, ya que i corresponde al número y j al valor total. Podemos especificar el color, que será negro, y el tamaño de la fuente, que será pequeño, 8.5. Adicionalmente, podemos definir la alineación horizontal, que será a la izquierda, y la alineación vertical, que será al centro de la barra.
#
# De esta manera, haremos la anotación al lado derecho de cada una de estas barras. Al ejecutar el código, ya tendremos los valores exactos, sin estimaciones. Por ejemplo, en Surinam, el total de inmigrantes fue de 739. En Chile y Venezuela, prácticamente están empatados, con 21,359 y 21,267 inmigrantes respectivamente. En Colombia, hubo 72,088 inmigrantes hacia Canadá durante el periodo de 1980-2013.

# %%
#COLOCAR EL NUMERO DE INMIGRANTES EN LAS BARRAS DEL GRAFICO

sudamerica_sorted = sudamerica.sort_values('Total',ascending = True)
colores=[]

for pais in sudamerica_sorted.index:
  if pais == 'Colombia':
    colores.append('green')
  else:
    colores.append('silver')

fig, ax =plt.subplots(figsize=(15,5))

ax.set_frame_on(False) #QUITA EL MARCO QUE RODEA EL GRAFICO
ax.xaxis.set_visible(False) #QUIA EL EJE X (DEBAJO DEL GRAFICO)
ax.tick_params(axis='y', which='both',length=0) #QUITA LOS GUIONES O RAYAS QUE SE ENCUENTRAN AL LADO DE LOS NOMBRES DE LOS PAISES AL COMIENZO DE LAS BARRAS

ax.barh(sudamerica_sorted.index, sudamerica_sorted['Total'],color=colores) #barh COLOCA LAS BARRAS DEL GRAFICO HORIZONTALES
ax.set_title('Sudamérica: Colombia es el segundo pais con mas migrantes\nhacia Canada durante el periodo de 1980 - 2013', loc='left', fontsize=18)
ax.set_ylabel('')
#ax.set_xlabel('Número de inmigrantes', fontsize=14)
#ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=10)

for i,j in enumerate(sudamerica_sorted['Total']):
  ax.text(j+20,i,str(j),color='black',fontsize=8.5, ha='left',va='center')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,3))
ax.plot(datos_col['Año'],datos_col['Inmigrantes'], lw=3, marker='o', color='g') # lw ES PARA EL GROSOR DE LA LINEA Y marker PARA AGREGAR LOS PUNTOS EN LA LINEA y color apra cmabiar el color de la linea
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) # COLOCAR LA MEJOR LOCACION DE 5 EN 5
ax.set_title('inmigracion de Colombianos hacia Canada\n1980 - 2013', fontsize=18, loc='left') # fontsize TAMAÑO DE LA FUENTE Y loc ALINEACIÓN DEL TITULO
ax.set_xlabel('Año', fontsize=14) #fontsize TAMAÑO DE LA LETRAS
ax.set_ylabel('Numero de inmigrantes', fontsize=14) #fontsize TAMAÑO DE LA FUENTE
ax.yaxis.set_tick_params(labelsize=12) #fontsize TAMAÑO DE LA FUENTE
ax.xaxis.set_tick_params(labelsize=12) #fontsize TAMAÑO DE LA FUENTE

ax.spines['top'].set_visible(False) #QUITA EL MARCO DE ARRIBA DEL GRAFICO
ax.spines['right'].set_visible(False) #QUITA EL MARCO DE LA DERECHA DEL GRAFICO

plt.show()

# %%
#GUARDAR EL GRAFICO EN UN ARCHIVO

fig, ax = plt.subplots(figsize=(8,3))
ax.plot(datos_col['Año'],datos_col['Inmigrantes'], lw=3, marker='o', color='g') # lw ES PARA EL GROSOR DE LA LINEA Y marker PARA AGREGAR LOS PUNTOS EN LA LINEA y color apra cmabiar el color de la linea
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) # COLOCAR LA MEJOR LOCACION DE 5 EN 5
ax.set_title('inmigracion de Colombianos hacia Canada\n1980 - 2013', fontsize=18, loc='left') # fontsize TAMAÑO DE LA FUENTE Y loc ALINEACIÓN DEL TITULO
ax.set_xlabel('Año', fontsize=14) #fontsize TAMAÑO DE LA LETRAS
ax.set_ylabel('Numero de inmigrantes', fontsize=14) #fontsize TAMAÑO DE LA FUENTE
ax.yaxis.set_tick_params(labelsize=12) #fontsize TAMAÑO DE LA FUENTE
ax.xaxis.set_tick_params(labelsize=12) #fontsize TAMAÑO DE LA FUENTE

ax.spines['top'].set_visible(False) #QUITA EL MARCO DE ARRIBA DEL GRAFICO
ax.spines['right'].set_visible(False) #QUITA EL MARCO DE LA DERECHA DEL GRAFICO

#GUARDAR EL GRAFICO EN ARCHIVO PNG CON EL FONDO SIN TRANSPARENCIA transparent=False,
#CON 300 DPI dpi=300 PARA EL ARCHIVO NO PESE TANTO
#Y bbox_inches='tight' PARA QUE NO TENGA MUCHO MARGEN ALREDEDOR
fig.savefig('/content/Inmigrantes_colombianos_canada.png', transparent=False, dpi=300, bbox_inches='tight')


plt.show()

# %% [markdown]
# #**09 Desafío: personalizando los subplots con los datos de ventas de tiendas diferentes**
#
# Cambiar la posición de los títulos de los subgráficos a la izquierda.
# Aumentar el tamaño de la fuente del título general de la figura para resaltarlo.
# Aumentar el tamaño de los títulos y etiquetas de los ejes de los subgráficos.
# Hacer que las líneas sean más gruesas.
# Cambiar el color de las líneas de cada tienda para diferenciarlas aún más.
#
# Recuerda que los datos son los siguientes:
#
# tiendas = ['A', 'B', 'C', 'D']
#
# ventas_2022 = {'Ene': [100, 80, 150, 50],
#     'Feb': [120, 90, 170, 60],
#     'Mar': [150, 100, 200, 80],
#     'Abr': [180, 110, 230, 90],
#     'May': [220, 190, 350, 200],
#     'Jun': [230, 150, 280, 120],
#     'Jul': [250, 170, 300, 140],
#     'Ago': [260, 180, 310, 150],
#     'Sep': [240, 160, 290, 130],
#     'Oct': [220, 140, 270, 110],
#     'Nov': [400, 220, 350, 190],
#     'Dec': [300, 350, 400, 250]}

# %%
# Crear la figura y los subgráficos
fig2, axs2 = plt.subplots(2, 2, figsize=(14, 8))

# Ajustar los espaciados entre los subgráficos
plt.subplots_adjust(wspace=0.3, hspace=0.4)

# Agregar un título general a los subgráficos
fig2.suptitle('Ventas en el periodo de enero a diciembre de 2022 en las tiendas A, B, C y D', fontsize=20)

# Lista de colores
colores = ['darkviolet', 'green', 'darkblue', 'coral']

# Bucle para trazar y personalizar los subgráficos
for i, ax in enumerate(axs2.flat):
    ax.plot(tiendas_ventas_2022.loc[tiendas_ventas_2022.index[i]], color=colores[i], lw=3)
    ax.set_title(f'Ventas en la tienda {df.index[i]}', loc='left', fontsize=16)
    ax.set_xlabel('Mes', fontsize=14)
    ax.set_ylabel('Número de ventas', fontsize=14)
    ax.tick_params(labelsize=12)
    ax.grid(color='lightgrey')

# %% [markdown]
# #**Seaborn**

# %%
#IMPORTAR LA LIBRERIA seaborn
import seaborn as sns

# %%
#DEFINIR EL TEMA DE seaborn PREDETERMINADO

sns.set_theme()

# %% [markdown]
# La función set_style() de la biblioteca Seaborn permite definir el estilo del gráfico. Cuando no se pasa ningún argumento a la función, utiliza el estilo predeterminado "darkgrid" de la biblioteca Seaborn.

# %%
#OBTENER LOS PRIMEROS 10 FILAS DEL DATAFRAME

top_10 = df.sort_values('Total', ascending=False).head(10)

top_10
# Out:
#                        Continente             Region   1980   1981   1982  \
# Pais
# India                        Asia        Sur de Asia   8880   8670   8147
# China                        Asia      Asia Oriental   5123   6682   3308
# Reino Unido                Europa    Norte de Europa  22045  24796  20620
# Filipinas                    Asia   Sudeste Asiático   6051   5921   5249
# Pakistán                     Asia        Sur de Asia    978    972   1201
# Estados Unidos  América del Norte  América del Norte   9378  10030   9074
# Irán                         Asia        Sur de Asia   1172   1429   1822
# Sri Lanka                    Asia        Sur de Asia    185    371    290
# Corea del Sur                Asia      Asia Oriental   1011   1456   1572
# Polonia                    Europa    Europa Oriental    863   2930   5881
#
#                  1983   1984  1985  1986   1987  ...   2005   2006   2007  \
# Pais                                             ...
# ...

# %%
#CREAR EL GRAFICO CON seaborn

sns.barplot(data=top_10,x='Total',y=top_10.index,orient='h')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))

ax = sns.barplot(data=top_10, x='Total',y=top_10.index,orient='h')
ax.set_title('Top 10 paises con mayor migración hacia Canadá\n1980 - 2013', loc='left', fontsize=16)
ax.set_xlabel('Número de inmigrantes', fontsize=14)
ax.set_ylabel('')
plt.show()

# %%
#FUNCION PARA GENERAR LOS GRAFICOS CON DIFERENTES PALETAS

def generar_grafico(palette):
  fig, ax = plt.subplots(figsize=(8,4))
  ax.set_frame_on(False)
  ax.xaxis.set_visible(False)
  ax.tick_params(axis='y',which='both',size=0)
  ax = sns.barplot(data=top_10, x='Total',y=top_10.index,orient='h', hue='Pais',  palette=palette, legend=False)
  ax.set_title('Top 10 paises con mayor migración hacia Canadá\n1980 - 2013', loc='left', fontsize=16)
  ax.set_xlabel('Número de inmigrantes', fontsize=14)
  ax.set_ylabel('')

  for i,j in enumerate(top_10['Total']):
    ax.text(j+20,i,str(j),color='black',fontsize=9, ha='left',va='center')
  plt.show()

# %%
#GENERAR GRAFICO CON PALETA Blues_r

generar_grafico('Blues_r')

# %%
#GENERAR GRAFICO CON PALETA rocket

generar_grafico('rocket')

# %%
#GENERAR GRAFICO CON PALETA coolwarm

generar_grafico('coolwarm')

# %%
#GENERAR GRAFICO CON PALETA Paired

generar_grafico('Paired')

# %%
#GENERAR GRAFICO CON PALETA tab10

generar_grafico('tab10')

# %%
#OTRA FUNCION PARA GENERAR LOS GRAFICOS CON DIFERENTES PALETAS Y DISEÑO EN seaborn

def generar_grafico2(palette):
  fig, ax = plt.subplots(figsize=(8,4))
  ax.set(xticklabels=[])
  ax.tick_params(axis='y',which='both',size=0)
  ax = sns.barplot(data=top_10, x='Total',y=top_10.index,orient='h', hue='Pais',  palette=palette, legend=False)
  ax.set_title('Top 10 paises con mayor migración hacia Canadá\n1980 - 2013', loc='left', fontsize=16)
  ax.set_xlabel('Número de inmigrantes', fontsize=14)
  ax.set_ylabel('')
  sns.despine()#QUITAR LOS MARCOS DEL GRAFICO

  for i,j in enumerate(top_10['Total']):
    ax.text(j+20,i,str(j),color='black',fontsize=9, ha='left',va='center')
  plt.show()

# %%
generar_grafico2('tab10')

# %%
#COLOCAR OTRO DISEÑO POR DEFECTO
sns.set_theme(style='darkgrid')
generar_grafico2('tab10')

# %%
sns.set_theme(style='whitegrid')
generar_grafico2('tab10')

# %%
sns.set_theme(style='white')
generar_grafico2('tab10')

# %% [markdown]
# #**08 Desafío: creando un gráfico de líneas con Seaborn**
#
# En esta etapa, tu desafío es crear una figura que muestre las tendencias de inmigración de los 4 mayores países de América Latina: Brasil, Argentina, Perú y Colombia. A través de esta creación, puedes explorar diversas posibilidades y mostrar de manera atractiva tu proceso de desarrollo. Y no nos olvidemos de las indicaciones. Esta figura debe tener una línea para cada país, título, etiquetas en los ejes, colores apropiados, un tema de la biblioteca Seaborn y una leyenda. Por lo tanto, piensa en cuestiones de accesibilidad, como el tamaño de las fuentes y el grosor de las líneas. Es importante elegir colores adecuados que no causen fatiga visual o dificulten la lectura de la información. Además, el tamaño de las fuentes debe ser lo suficientemente legible para que las personas puedan interpretar los datos fácilmente.
#
# Consejo: para elegir la paleta de colores, también puedes consultar la documentación de la biblioteca Matplotlib. Seaborn utiliza los colormaps de Matplotlib por defecto, además de ofrecer sus propias paletas de colores. Para aplicar una paleta de colores a todas las líneas de la figura, puedes usar la función sns.set_palette() y pasarle el nombre de la paleta elegida.

# %%
sns.set_theme()
sns.set_palette('Dark2')

fig, ax = plt.subplots(figsize=(10, 5))
ax = sns.lineplot(df.loc['Brasil', anos], label='Brasil', lw=3)
ax = sns.lineplot(df.loc['Argentina', anos], label='Argentina', lw=3)
ax = sns.lineplot(df.loc['Perú', anos], label='Perú', lw=3)
ax = sns.lineplot(df.loc['Colombia', anos], label='Colombia', lw=3)

ax.set_title('Inmigración de los principales países de América del Sur\nal Canadá de 1980 a 2013', loc='left', fontsize=20)
ax.set_xlabel('Año', fontsize=14)
ax.set_ylabel('Número de Inmigrantes', fontsize=14)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))#MEJOR UBICACION PARA LOS AÑOS DE 5 EN 5
ax.legend(title='Países', loc='upper right', bbox_to_anchor=(1.18, 1.02))#TITULO Y UBICACION DE LA LEYENDA

plt.show()

# %% [markdown]
# #**Plotly**

# %%
import plotly.express as px

# %%
#CREAR GRAFICO DINAMICO CON plotly

fig = px.line(datos_col, x='Año', y='Inmigrantes', title='Inmigración de Colombianos hacia Canadá entre 1980 y 2013')
fig.update_traces(line_color='green',line_width=4)
fig.update_layout(width=600,height=400,xaxis={'tickangle':-45}, xaxis_title='Año',yaxis_title='Número de inmigrantes',
                  font_family='Arial',font_size=14, font_color='grey')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#OBTENER DATOS DEL DATAFRAME CON PAISES DE SUDAMERICA PARA GRAFICARLO CON plotly

sudamerica.drop(['Continente','Region','Total'], axis=1, inplace=True)#drop ELIMINA LAS COLUMNAS QUE NO VAMOS A UTILIZAR
sudamerica
# Out:
# <ipython-input-52-adde0f2d4758>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  ...  \
# Pais                                                                   ...
# Argentina   368   426   626   241   237   196   213   519   374   538  ...
# Bolivia      44    52    42    49    38    44    79   165    63    68  ...
# Brasil      211   220   192   139   145   130   205   244   394   650  ...
# Chile      1233  1069  1078   781   681   533   633  1454   990  1023  ...
# Colombia    266   326   360   244   235   214   257   376   352   439  ...
# Ecuador     238   207   184   155   179   208   240   344   265   278  ...
# Guyana     2334  2943  3575  2650  1932  2299  3942  6174  2977  3270  ...
# ...

# %%
#TRANSPONEMOS LOS DATOS

sudamerica = sudamerica.T

sudamerica
# Out:
# Pais  Argentina  Bolivia  Brasil  Chile  Colombia  Ecuador  Guyana  Paraguay  \
# 1980        368       44     211   1233       266      238    2334        45
# 1981        426       52     220   1069       326      207    2943        26
# 1982        626       42     192   1078       360      184    3575        32
# 1983        241       49     139    781       244      155    2650        40
# 1984        237       38     145    681       235      179    1932        48
# 1985        196       44     130    533       214      208    2299        36
# 1986        213       79     205    633       257      240    3942        34
# 1987        519      165     244   1454       376      344    6174        72
# 1988        374       63     394    990       352      265    2977        53
# 1989        538       68     650   1023       439      278    3270        48
# 1990        678       71     650   1286       614      552    2824        56
# ...

# %%
#CREAR GRAFICO DINAMICO CON plotly

fig = px.line(sudamerica, x=sudamerica.index, y=sudamerica.columns, title='Inmigración de sudamericanos hacia Canadá entre 1980 y 2013', color='Pais', markers=True)
fig.update_layout(width=1200,height=600,xaxis={'tickangle':-45}, xaxis_title='Año',yaxis_title='Número de inmigrantes',
                  font_family='Arial',font_size=14, font_color='grey')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#EXPORTAR GRAFICO EN HTML

fig = px.line(sudamerica, x=sudamerica.index, y=sudamerica.columns, title='Inmigración de sudamericanos hacia Canadá entre 1980 y 2013', color='Pais', markers=True)
fig.update_layout(width=1200,height=600,xaxis={'tickangle':-45}, xaxis_title='Año',yaxis_title='Número de inmigrantes',
                  font_family='Arial',font_size=14, font_color='grey')

fig.write_html('/content/inmigracion_sudamericanos_canada.html')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Animación de gráficos para mostrar cambios durante un lapso

'''
Creamos un bloque de código donde construiremos esta animación, importando plotly.graph_objs,
un módulo de la biblioteca Plotly que contiene clases para crear visualizaciones de datos interactivas y personalizadas.
'''
import plotly.graph_objs as go

'''
Después de obtener el DataFrame solo con los datos de Colombia, como hicimos al principio del curso,
cambia el tipo de datos de la columna que contiene los años a int en lugar de mantenerlos como strings:
'''
datos_col['Año'] = datos_col['Año'].astype(int)


'''
A continuación, se crea una figura vacía usando la función go.Figure() y se asigna a la variable fig.
'''
# Criando uma figura
fig = go.Figure()


'''
Luego, se agrega una línea al gráfico usando la función fig.add_trace(). En esta función,
se pasa un objeto Scatter, que recibe como argumentos los datos para los ejes X e Y del gráfico.
Para que el gráfico se muestre sin línea antes de hacer clic en el botón de reproducción,
usamos iloc[0] en ambas variables. Esto se debe a que iloc[0] selecciona el primer valor de las columnas año
e inmigrantes de los datos de Brasil, respectivamente. Al agregar este punto de datos a la visualización del
gráfico, inicialmente se mostrará como un solo punto, sin líneas que lo conecten a otros puntos. Además,
pasamos el modo de visualización lines, que significa líneas, y el nombre de la línea. También se define el
grosor de la línea usando el diccionario line=dict(width=4).
'''
# Adicionando a linha do gráfico e definindo a espessura da linha
fig.add_trace(
    go.Scatter(x=[datos_col['Año'].iloc[0]], y=[datos_col['Inmigrantes'].iloc[0]], mode='lines', name='Inmigrantes', line=dict(width=4))
)


'''
Después de eso, se definen el título del gráfico y las configuraciones de
los ejes X e Y usando la función fig.update_layout(). Los argumentos del título son:

text='<b>Inmigración de Colombianos hacia Canadá en el periodo de 1980 a 2013</b>': define el texto del título como
una cadena formateada en negrita (usando las etiquetas HTML "<b>" y "</b>")

x=0.12: define la posición horizontal del título en el diseño, en relación con el ancho de la figura.
El valor 0.12 especifica que el título comenzará al 12% del ancho de la figura.

xanchor='left': define la alineación horizontal del título. El valor 'left' significa que el título se
alineará a la izquierda del diseño.

font=dict(size=20): define el tamaño del texto del título.
Los argumentos para xaxis y yaxis son diccionarios, con las siguientes propiedades:

range=[1980, 2013]: define el rango del eje, es decir, el valor mínimo y máximo que se mostrarán.
En este caso, el eje x tendrá como valor mínimo 1980 y como valor máximo 2013, mientras que el eje
 y tendrá como valor mínimo 0 y como valor máximo 7000.

autorange=False: define si los límites del eje se ajustarán automáticamente (True) o no (False).
En este caso, los límites no se ajustarán automáticamente.

title='<b>Año</b>': define el título del eje. En este caso, el eje x tendrá el título "Año",
que está formateado en negrita (usando las etiquetas HTML "" y "").

title='<b>Número de Inmigrantes</b>': define el título del eje. En este caso, el eje y
tendrá el título "Número de Inmigrantes", que está formateado en negrita
(usando las etiquetas HTML "<b>" y "</b>").
'''
# Definir la configuración del layout
fig.update_layout(
    title=dict(
        text='<b>Inmigración de Colombianos hacia Canadá en el periodo de 1980 a 2013</b>',
        x=0.12,
        xanchor='left',
        font=dict(size=20)
    ),
    xaxis=dict(range=[1980, 2013], autorange=False, title='<b>Año</b>'),
    yaxis=dict(range=[0, 7000], autorange=False, title='<b>Número de Inmigrantes</b>'),

    #Se agrega un botón "Play" para la animación usando el argumento updatemenus.
    #Este argumento es una lista que define las opciones de menú para la figura.
    #El valor asignado a esta lista es un diccionario, con las siguientes propiedades:
    #type='buttons': define que el menú estará compuesto por botones.
    #showactive=False: define que ningún botón estará activo inicialmente.
    #buttons=[dict(label='Play', method='animate',
    #args=[None, {'frame': {'duration': 100, 'redraw': True}, 'fromcurrent': True}])]:
    #Define el botón que se mostrará en el menú. Este botón tiene la etiqueta "Play" (es decir, "reproducir"),
    #que se muestra en el propio botón. El método animate se utiliza para activar la animación de los datos.
    #El argumento args es una lista que contiene dos elementos: el primero es None,
    #indicando que ningún trace (o capa) del gráfico será afectado por la animación, y el segundo es
    #un diccionario que especifica los parámetros de la animación. El parámetro frame define la duración
    #de cada cuadro de la animación y la actualización de cada cuadro. El parámetro fromcurrent determina
    #si se debe mantener el cuadro actual o si la animación debe comenzar desde el primer cuadro.

    updatemenus=[dict(
        type='buttons',
        showactive=False,
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None, {'frame': {'duration': 100, 'redraw': True}, 'fromcurrent': True}]
        )]
    )],

    #La anchura (width) y la altura (height) del gráfico
    #se definen respectivamente como 1000 y 500.

    width=1000,
    height=500
)

'''
Las configuraciones de animación se especifican mediante la variable frames,
que es una lista de objetos Frame de Plotly, conteniendo los datos para cada cuadro de la animación.
Cada Frame contiene un trace, que en este caso es un objeto Scatter representando un punto en el gráfico,
donde X es el año y Y es el número de inmigrantes. Un bucle for se utiliza para
crear un objeto Frame para cada año en el conjunto de datos, añadiendo un punto
adicional al gráfico en cada iteración.

Finalmente, la lista frames se asigna a la propiedad frames del objeto Figure (fig) creado anteriormente,
lo que permite que la animación se muestre en el gráfico cuando se presiona el botón de control de animación.
Cada Frame contiene los datos del gráfico para un año específico
y se muestra secuencialmente al presionar el botón "Play".
'''
# Definir la configuración de la animación
frames = [go.Frame(data=[go.Scatter(x=datos_col['Año'].iloc[:i+1], y=datos_col['Inmigrantes'].iloc[:i+1])]) for i in range(len(datos_col))]
fig.frames = frames

'''
La función fig.show() se llama al final para mostrar el gráfico animado en el notebook.
Al presionar el botón "Play", el gráfico se animará,
mostrando la inmigración de Brasil a Canadá desde 1980 hasta 2013.
'''
# Mostrar la figura
fig.show()

'''
Este enfoque ilustra cómo se pueden crear animaciones dinámicas utilizando Plotly,
no solo para líneas sino también para puntos, barras, mapas y mucho más, aprovechando
la amplia gama de herramientas y características que ofrece Plotly para crear
visualizaciones interactivas y atractivas.
'''
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #**Desafío: creando una animación para comparar diferentes datos**
#  Siguiente pregunta
#
# En la actividad anterior, fue posible comprender cómo crear una animación con la biblioteca Plotly. ¡Ahora viene otro desafío!
#
# ¿Recuerdas que creamos una figura estática que contiene los datos de inmigración de Brasil y Argentina? Tu tarea es crear un gráfico animado con Plotly que muestre estos datos. El gráfico debe tener las siguientes características:
#
# - Dos líneas: una para Brasil y otra para Argentina.
#
# - Un botón "Play" para iniciar la animación, mostrando el aumento o disminución del número de inmigrantes a lo largo de los años.
#
# - Las configuraciones de animación deben hacer que las dos líneas se muestren y animen al mismo tiempo.
# Consejos:
#
# - Crea un DataFrame con los datos de Argentina y no olvides dejar la columna de años como tipo int (entero).
#
# - Utiliza el código proporcionado para Brasil como base y adáptalo para incluir los datos de Argentina.
#
# Para configurar las animaciones, puedes hacer un bucle for para recorrer el DataFrame datos_brasil y, para cada iteración, crear una nueva lista que contenga dos objetos del tipo go.Scatter, uno para cada país. Luego, cada lista puede ser utilizada para crear un objeto go.Frame, que se agrega a la lista de frames. Finalmente, la lista de frames puede ser asignada al objeto fig, que es la figura del gráfico que se animará. Con esto, cuando se inicie la animación, el gráfico mostrará las dos líneas en movimiento, una para Brasil y otra para Argentina.

# %%
#CREAR EL GRAFICO CON LOS DATOS OBTENIDOS

plt.plot(df_comparacion['Brasil'], label='Brasil')
plt.plot(df_comparacion['Argentina'], label='Argentina')
plt.title('Inmigración de Brasil y Argentina a Canadá')
plt.xlabel('Año')
plt.ylabel('Número de Inmigrantes')
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.legend()
plt.show()

# %%
brasil = df.loc['Brasil',anos]
bra_dic = {'Año':brasil.index.tolist(), 'Inmigrantes':brasil.values.tolist()}
datos_brasil = pd.DataFrame(bra_dic)
datos_brasil['Año'] = datos_brasil['Año'].astype(int)
datos_brasil
# Out:
#      Año  Inmigrantes
# 0   1980          211
# 1   1981          220
# 2   1982          192
# 3   1983          139
# 4   1984          145
# 5   1985          130
# 6   1986          205
# 7   1987          244
# 8   1988          394
# 9   1989          650
# 10  1990          650
# 11  1991          877
# 12  1992         1066
# 13  1993          866
# 14  1994          566
# 15  1995          572
# 16  1996          586
# 17  1997          591
# 18  1998          531
# 19  1999          626
# 20  2000          845
# 21  2001          847
# 22  2002          745
# 23  2003          839
# 24  2004          917
# 25  2005          969
# 26  2006         1181
# 27  2007         1746
# 28  2008         2138
# 29  2009         2509
# 30  2010         2598
# 31  2011         1508
# 32  2012         1642
# 33  2013         1714

# %%
argentina = df.loc['Argentina',anos]
arg_dic = {'Año':argentina.index.tolist(), 'Inmigrantes':argentina.values.tolist()}
datos_argentina = pd.DataFrame(arg_dic)
datos_argentina['Año'] = datos_argentina['Año'].astype(int)
#datos_argentina

datos_argentina
# Out:
#      Año  Inmigrantes
# 0   1980          368
# 1   1981          426
# 2   1982          626
# 3   1983          241
# 4   1984          237
# 5   1985          196
# 6   1986          213
# 7   1987          519
# 8   1988          374
# 9   1989          538
# 10  1990          678
# 11  1991          763
# 12  1992         1023
# 13  1993         1022
# 14  1994          366
# 15  1995          380
# 16  1996          396
# 17  1997          391
# 18  1998          349
# 19  1999          318
# 20  2000          427
# 21  2001          635
# 22  2002          865
# 23  2003         1745
# 24  2004         1591
# 25  2005         1153
# 26  2006          847
# 27  2007          620
# 28  2008          540
# 29  2009          467
# 30  2010          459
# 31  2011          278
# 32  2012          263
# 33  2013          282

# %%
#Animación de gráficos para mostrar cambios durante un lapso

'''
Creamos un bloque de código donde construiremos esta animación, importando plotly.graph_objs,
un módulo de la biblioteca Plotly que contiene clases para crear visualizaciones de datos interactivas y personalizadas.
'''
import plotly.graph_objs as go

'''
Después de obtener el DataFrame solo con los datos de Colombia, como hicimos al principio del curso,
cambia el tipo de datos de la columna que contiene los años a int en lugar de mantenerlos como strings:
'''
#datos_col['Año'] = datos_col['Año'].astype(int)


'''
A continuación, se crea una figura vacía usando la función go.Figure() y se asigna a la variable fig.
'''
# Criando uma figura
fig = go.Figure()


'''
Luego, se agrega una línea al gráfico usando la función fig.add_trace(). En esta función,
se pasa un objeto Scatter, que recibe como argumentos los datos para los ejes X e Y del gráfico.
Para que el gráfico se muestre sin línea antes de hacer clic en el botón de reproducción,
usamos iloc[0] en ambas variables. Esto se debe a que iloc[0] selecciona el primer valor de las columnas año
e inmigrantes de los datos de Brasil, respectivamente. Al agregar este punto de datos a la visualización del
gráfico, inicialmente se mostrará como un solo punto, sin líneas que lo conecten a otros puntos. Además,
pasamos el modo de visualización lines, que significa líneas, y el nombre de la línea. También se define el
grosor de la línea usando el diccionario line=dict(width=4).
'''
# Adicionando a linha do gráfico e definindo a espessura da linha
fig.add_trace(
    go.Scatter(x=[datos_brasil['Año'].iloc[0]], y=[datos_brasil['Inmigrantes'].iloc[0]], mode='lines', name='Inmigrantes de Brasil', line=dict(width=4))
)

fig.add_trace(
    go.Scatter(x=[datos_argentina['Año'].iloc[0]], y=[datos_argentina['Inmigrantes'].iloc[0]], mode='lines', name='Inmigrantes de Argentina', line=dict(width=4))
)

'''
Después de eso, se definen el título del gráfico y las configuraciones de
los ejes X e Y usando la función fig.update_layout(). Los argumentos del título son:

text='<b>Inmigración de Colombianos hacia Canadá en el periodo de 1980 a 2013</b>': define el texto del título como
una cadena formateada en negrita (usando las etiquetas HTML "<b>" y "</b>")

x=0.12: define la posición horizontal del título en el diseño, en relación con el ancho de la figura.
El valor 0.12 especifica que el título comenzará al 12% del ancho de la figura.

xanchor='left': define la alineación horizontal del título. El valor 'left' significa que el título se
alineará a la izquierda del diseño.

font=dict(size=20): define el tamaño del texto del título.
Los argumentos para xaxis y yaxis son diccionarios, con las siguientes propiedades:

range=[1980, 2013]: define el rango del eje, es decir, el valor mínimo y máximo que se mostrarán.
En este caso, el eje x tendrá como valor mínimo 1980 y como valor máximo 2013, mientras que el eje
 y tendrá como valor mínimo 0 y como valor máximo 7000.

autorange=False: define si los límites del eje se ajustarán automáticamente (True) o no (False).
En este caso, los límites no se ajustarán automáticamente.

title='<b>Año</b>': define el título del eje. En este caso, el eje x tendrá el título "Año",
que está formateado en negrita (usando las etiquetas HTML "" y "").

title='<b>Número de Inmigrantes</b>': define el título del eje. En este caso, el eje y
tendrá el título "Número de Inmigrantes", que está formateado en negrita
(usando las etiquetas HTML "<b>" y "</b>").
'''
# Definir la configuración del layout
fig.update_layout(
    title=dict(
        text='<b>Inmigración de Brasil y Argentina hacia Canadá en el periodo de 1980 a 2013</b>',
        x=0.12,
        xanchor='left',
        font=dict(size=20)
    ),
    xaxis=dict(range=[1980, 2013], autorange=False, title='<b>Año</b>'),
    yaxis=dict(range=[0, 3000], autorange=False, title='<b>Número de Inmigrantes</b>'),

    #Se agrega un botón "Play" para la animación usando el argumento updatemenus.
    #Este argumento es una lista que define las opciones de menú para la figura.
    #El valor asignado a esta lista es un diccionario, con las siguientes propiedades:
    #type='buttons': define que el menú estará compuesto por botones.
    #showactive=False: define que ningún botón estará activo inicialmente.
    #buttons=[dict(label='Play', method='animate',
    #args=[None, {'frame': {'duration': 100, 'redraw': True}, 'fromcurrent': True}])]:
    #Define el botón que se mostrará en el menú. Este botón tiene la etiqueta "Play" (es decir, "reproducir"),
    #que se muestra en el propio botón. El método animate se utiliza para activar la animación de los datos.
    #El argumento args es una lista que contiene dos elementos: el primero es None,
    #indicando que ningún trace (o capa) del gráfico será afectado por la animación, y el segundo es
    #un diccionario que especifica los parámetros de la animación. El parámetro frame define la duración
    #de cada cuadro de la animación y la actualización de cada cuadro. El parámetro fromcurrent determina
    #si se debe mantener el cuadro actual o si la animación debe comenzar desde el primer cuadro.

    updatemenus=[dict(
        type='buttons',
        showactive=False,
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None, {'frame': {'duration': 100, 'redraw': True}, 'fromcurrent': True}]
        )]
    )],

    #La anchura (width) y la altura (height) del gráfico
    #se definen respectivamente como 1000 y 500.

    width=1000,
    height=500
)

'''
Las configuraciones de animación se especifican mediante la variable frames,
que es una lista de objetos Frame de Plotly, conteniendo los datos para cada cuadro de la animación.
Cada Frame contiene un trace, que en este caso es un objeto Scatter representando un punto en el gráfico,
donde X es el año y Y es el número de inmigrantes. Un bucle for se utiliza para
crear un objeto Frame para cada año en el conjunto de datos, añadiendo un punto
adicional al gráfico en cada iteración.

Finalmente, la lista frames se asigna a la propiedad frames del objeto Figure (fig) creado anteriormente,
lo que permite que la animación se muestre en el gráfico cuando se presiona el botón de control de animación.
Cada Frame contiene los datos del gráfico para un año específico
y se muestra secuencialmente al presionar el botón "Play".
'''
# Definir la configuración de la animación
frames = []
for i in range(len(datos_argentina)):
  frame_data = [
      go.Scatter(x=datos_brasil['Año'].iloc[:i+1], y=datos_brasil['Inmigrantes'].iloc[:i+1]),
      go.Scatter(x=datos_argentina['Año'].iloc[:i+1], y=datos_argentina['Inmigrantes'].iloc[:i+1])
  ]
  frame = go.Frame(data=frame_data)
  frames.append(frame)

fig.frames = frames
'''
La función fig.show() se llama al final para mostrar el gráfico animado en el notebook.
Al presionar el botón "Play", el gráfico se animará,
mostrando la inmigración de Brasil a Canadá desde 1980 hasta 2013.
'''
# Mostrar la figura
fig.show()

'''
Este enfoque ilustra cómo se pueden crear animaciones dinámicas utilizando Plotly,
no solo para líneas sino también para puntos, barras, mapas y mucho más, aprovechando
la amplia gama de herramientas y características que ofrece Plotly para crear
visualizaciones interactivas y atractivas.
'''
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
